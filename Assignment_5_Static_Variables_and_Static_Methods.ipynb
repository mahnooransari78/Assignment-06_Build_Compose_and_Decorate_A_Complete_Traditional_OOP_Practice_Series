# %% [markdown]
# <a href="https://colab.research.google.com/github/mahnooransari78/Assignment-06_Build_Compose_and_Decorate_A_Complete_Traditional_OOP_Practice_Series/blob/main/Assignment_5_Static_Variables_and_Static_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 5. Static Variables and Static Methods
# Assignment:
# Create a class MathUtils with a static method add(a, b) that returns the sum. No class or instance variables should be used.

class MathUtils:
  @staticmethod
  def add(a, b):
    return a + b

# Static method ko directly class ke through call karte hain
result = MathUtils.add(12, 16)
print("Sum is: ", result)

# Output:
# Sum is:  28
# Out:
# Sum is:  28
