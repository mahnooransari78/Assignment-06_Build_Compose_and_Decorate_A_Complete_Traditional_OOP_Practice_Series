# %% [markdown]
# <a href="https://colab.research.google.com/github/mahnooransari78/Assignment-06_Build_Compose_and_Decorate_A_Complete_Traditional_OOP_Practice_Series/blob/main/Assignment_20_Creating_a_Custom_Exception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 20. Creating a Custom Exception
# Assignment: Create a custom exception InvalidAgeError. Write a function check_age(age) that raises this exception if age < 18. Handle it with try...except.

class InvalidAgeError(Exception):
     pass

def check_age(age):
    if age < 18 :
        raise InvalidAgeError("Age must be 18 or older!")
    return "Age is valid."


try:
   age = 16
   result = check_age(age)
   print(result)
except InvalidAgeError as e:
    print(f"Error: {e}")
# Out:
# Error: Age must be 18 or older!
