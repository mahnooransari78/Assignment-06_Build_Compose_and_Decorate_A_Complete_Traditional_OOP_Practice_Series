# %% [markdown]
# <a href="https://colab.research.google.com/github/mahnooransari78/Assignment-06_Build_Compose_and_Decorate_A_Complete_Traditional_OOP_Practice_Series/blob/main/Assignment_6_Constructors_and_Destructors_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assignment: 6. Constructors and Destructors
# Create a class Logger that prints a message when an object is created (constructor) and another message when it is destroyed (destructor).

class Logger:
  def __init__(self):
    print("Logger Initialized: Object Created.")

  def __del__(delf):
    print("Logger Terminated: Object Destroyed.")

# Object create kar rahe hain
log1 = Logger()

# Optional: Manually delete object to trigger destructor immediately
del log1

# Note: Destructor kabhi kabhi program end hone par bhi automatically call hota hai
# Out:
# Logger Initialized: Object Created.
# Logger Terminated: Object Destroyed.
