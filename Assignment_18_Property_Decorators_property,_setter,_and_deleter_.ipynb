# %% [markdown]
# <a href="https://colab.research.google.com/github/mahnooransari78/Assignment-06_Build_Compose_and_Decorate_A_Complete_Traditional_OOP_Practice_Series/blob/main/Assignment_18_Property_Decorators_property%2C_setter%2C_and_deleter_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 18. Property Decorators: @property, @setter, and @deleter
# Assignment: Create a class Product with a private attribute _price. Use @property to get the price, @price.setter to update it, and @price.deleter to delete it.

class Product:
  def __init__(self, price):
    self._price = price

  @property
  def price(self):
    print("Getting price...")
    return self._price
  @price.setter
  def price(self, value):
    if value < 0 :
      raise ValueError("Price cannot be negative!")
    print("Setting price...")
    self._price = value

  @price.deleter
  def price(self):
    print("Deleting price...")
    del self._price

# Create product object
p = Product(100)

# Access price (calls @property)
print(p.price)  # Output: Getting price... 100

# Set new price (calls @setter)
p.price = 150  # Output: Setting price...

# Access updated price
print(p.price)  # Output: Getting price... 150

# Delete price (calls @deleter)
del p.price  # Output: Deleting price...
# Out:
# Getting price...
# 100
# Setting price...
# Getting price...
# 150
# Deleting price...
